# %% [markdown]
# <a href="https://colab.research.google.com/github/rca32/pythoncs_2019/blob/master/10_Class%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pydot
# !apt-get install fonts-nanum*
# !apt-get install fontconfig
# !fc-cache -fv
# !cp /usr/share/fonts/truetype/nanum/Nanum* /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/
# !rm -rf /content/.cache/matplotlib/*
import pydot
from IPython.core.display import Image 
#https://en.wikipedia.org/wiki/DOT_%28graph_description_language%29

# %%
command = """
digraph G {
  동물->강아지->불독
  강아지->러셀테리어
  }
"""
graph = pydot.graph_from_dot_data(command)[0]
image = graph.create_png()
Image(image)

# %%
command = """
digraph G {
  리스트--애완동물

  }
"""
  
graph = pydot.graph_from_dot_data(command)[0]
image = graph.create_png()
Image(image)

# %%
#@title 기본 제목 텍스트
# 강아지 목록 생성 
my_dogs = [
    불독("별이", 6), 
    러셀테리어("달이", 7), 
    강아지("멍멍이", 9)
]

 
my_pets = 애완동물(my_dogs)

 
print(f"현재 내가 보유한 애완동물의 마리수는 {my_pets.평균나이()}입니다.")
for pet in my_pets:
    print(f"이동물의 이름은 {pet.이름}이고  나이는 {pet.나이} 입니다. 또한 종은 {pet.품종}")
